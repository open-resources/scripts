# %%
import pandas as pd
import webbrowser

# %%
df = pd.read_csv('problem_bank_names.csv')

# %%
df['Names'].iloc[0]
# Out:
# 'PHYS100_Test04_P10FB'

# %%
stem='https://studio.edge.edx.org/export/library-v1:UBCx+'

# %%
# will open 100 windows

# for i in range(df['Names'].size):
#     webbrowser.open(stem+df['Names'].iloc[i])

# %%
subset=df[df['Names'].str.contains('FB')]
subset.head()
# Out:
#                   Names
# 0  PHYS100_Test04_P10FB
# 1   PHYS100_Test04_P9FB
# 2  PHYS100_Test05_P10FB
# 3    Phys100_Test1_P1FB
# 4    Phys100_Test1_P2FB

# %%
subset = subset.replace('Phys100_Test','PHYS100_Test0',regex=True)
subset
# Out:
#                    Names
# 0   PHYS100_Test04_P10FB
# 1    PHYS100_Test04_P9FB
# 2   PHYS100_Test05_P10FB
# 3    PHYS100_Test01_P1FB
# 4    PHYS100_Test01_P2FB
# 5    PHYS100_Test01_P3FB
# 6    PHYS100_Test01_P4FB
# 7    PHYS100_Test01_P5FB
# 8    PHYS100_Test01_P6FB
# 9    PHYS100_Test01_P7FB
# 10   PHYS100_Test01_P8FB
# 11   PHYS100_Test01_P9FB
# 22   PHYS100_Test02_P1FB
# 23   PHYS100_Test02_P2FB
# 24   PHYS100_Test02_P3FB
# 25   PHYS100_Test02_P4FB
# 26   PHYS100_Test02_P5FB
# 27   PHYS100_Test02_P6FB
# 28    PHYS100_Test2_P7FB
# 29   PHYS100_Test02_P8FB
# 30   PHYS100_Test02_P9FB
# 40   PHYS100_Test03_P1FB
# 41   PHYS100_Test03_P2FB
# 42   PHYS100_Test03_P3FB
# 43   PHYS100_Test03_P4FB
# 44   PHYS100_Test03_P5FB
# 45   PHYS100_Test03_P6FB
# 47   PHYS100_Test03_P7FB
# 48   PHYS100_Test03_P8FB
# 49   PHYS100_Test03_P9FB
# 62   PHYS100_Test04_P1FB
# 63   PHYS100_Test04_P2FB
# 64   PHYS100_Test04_P3FB
# 65   PHYS100_Test04_P4FB
# 66   PHYS100_Test04_P5FB
# 67   PHYS100_Test04_P6FB
# ...

# %%
# This will open about 39 tabs 

# for i in range(subset['Names'].size):
#     webbrowser.open(stem+subset['Names'].iloc[i])

# %% [markdown]
# ## Some manual fixing needed even after the above:
#
# - `PHYS100_Test05_P7FB` is actually `PHYS100_Test5_P7FB`
